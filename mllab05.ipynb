# %%
import pandas as pd
import numpy as np
#printing dataset
df=pd.read_csv("D:\extracted_features_charrec_dense7.csv")
df
# Out:
#               0         1          2    3          4          5          6  \
# 0     27.630783  0.000000  51.067493  0.0  26.302004   0.000000   0.000000
# 1     41.934185  0.000000  57.616398  0.0  40.345722   0.000000   0.000000
# 2     59.681458  0.000000  35.450397  0.0  51.084698   0.000000   0.000000
# 3     25.652845  0.000000  42.711246  0.0  26.391441   0.000000   0.000000
# 4     51.862490  0.000000  25.455917  0.0  48.505250   0.000000   0.000000
# ...         ...       ...        ...  ...        ...        ...        ...
# 6652   0.000000  8.917019  12.606703  0.0   0.000000  23.875010   0.000000
# 6653  12.088920  3.646342  28.106102  0.0   0.000000   0.000000   0.000000
# 6654   0.000000  0.000000  53.899130  0.0   0.000000   0.000000  12.079654
# 6655   0.000000  0.000000  37.811558  0.0   0.000000   0.000000   8.555406
# 6656   0.000000  0.000000  29.105694  0.0   0.000000   8.669491  20.568624
#
# ...

# %%
df.describe()
#describeing the dataset
# Out:
#                  0            1            2            3            4  \
# count  6657.000000  6657.000000  6657.000000  6657.000000  6657.000000
# mean     21.167244     7.914853    26.955550     0.001694    22.496025
# std      21.048915    11.119147    34.284395     0.044561    24.870716
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%      16.735703     2.248540    16.052292     0.000000    15.782615
# 75%      34.614826    11.951107    40.553830     0.000000    37.320180
# max     113.655290    58.710968   194.724120     1.568933   149.866410
#
#                  5            6            7       8            9  ...  \
# count  6657.000000  6657.000000  6657.000000  6657.0  6657.000000  ...
# mean      3.155892     0.566073     0.000942     0.0    25.541555  ...
# std       9.028120     3.395978     0.040107     0.0    35.277036  ...
# ...

# %%
import numpy as np

class Perceptron:
    def __init__(self, weights):
        self.weights = np.array(weights)
        self.iterations = 0  # Add a variable to track the number of iterations

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def predict(self, inputs):
        weighted_sum = np.dot(self.weights, inputs)
        return 1 if self.sigmoid(weighted_sum) >= 0.5 else 0

    def train(self, inputs, targets, learning_rate=0.05, max_iterations=1000):
        for epoch in range(max_iterations):
            error = 0
            for i in range(len(inputs)):
                prediction = self.predict(inputs[i])
                target = targets[i]
                error += (target - prediction) ** 2
                self.weights += learning_rate * (target - prediction) * inputs[i]
                self.iterations += 1  # Increment the iteration count

            if error <= 0.002:
                break

        print("Error after convergence:", error)

perceptron_sigmoid = Perceptron([10, 0.2, -0.75])
perceptron_sigmoid.train(training_data, training_targets)

print("Iterations taken with sigmoid function:", perceptron_sigmoid.iterations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 31
#      28         print("Error after convergence:", error)
#      30 perceptron_sigmoid = Perceptron([10, 0.2, -0.75])
# ---> 31 perceptron_sigmoid.train(training_data, training_targets)
#      33 print("Iterations taken with sigmoid function:", perceptron_sigmoid.iterations)
#
# NameError: name 'training_data' is not defined

# %%
import numpy as np
# Define the step activation function
def step(x):
    return np.where(x >= 0, 1, 0)

 

#the AND gate training data
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])

 

# the initial weights and learning rate are
w = np.array([10, 0.2, -0.75])
alpha = 0.05
#the convergence error threshold and maximum number of epochs
error_threshold = 0.002
max_epochs = 1000

 

# Initialize the error and epoch counters
errors = []
epochs = 0

 

# Train the perceptron
while True:
    # Calculate the net input
    net_input = np.dot(X, w[1:]) + w[0]

 

#Apply the activation function
    output = step(net_input)

 

#Calculate the error
    error = y - output

 

# Calculating the sum-squared error
    sse = np.sum(error ** 2)

 

# Append the error to the list
    errors.append(sse)

 

#Increment the epoch counter
    epochs += 1

 

    # Update the weights
    w[1:] += alpha * np.dot(X.T, error)
    w[0] += alpha * error.sum()

 

    # Check for convergence
    if sse <= error_threshold or epochs >= max_epochs:
        break
# Plot the errors
import matplotlib.pyplot as plt
plt.plot(errors)
plt.xlabel('Epochs')
plt.ylabel('Sum-squared error')
plt.show()
# Print the number of epochs needed for convergence
print('Number of epochs:', epochs)
# Out:
# Number of epochs: 130
